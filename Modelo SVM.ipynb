# %%
# %pip install keras
# %pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.utils import np_utils
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.decomposition import PCA

# %%
dfc = pd.read_csv('C:/Users/1032452285/Downloads/base_entrenamiento_2021_22_completa.csv')
#df = df.drop('Unnamed: 0', axis=1)
dfc= dfc.drop (['iddx','Usuario','DocumentoUsuario','DocumentoEmpresa','NUM_ID','NUM_MATRICULA','NOMBRE'], axis=1)
dfc.describe().applymap('{:,.2f}'.format)
# Out:
#       ULT_ANO_RENOVA AÑOS_FUNCIONAMIENTO PERSONAL2022  subseccion   CIIUFINAL  \
# count     665,385.00          665,385.00   665,385.00  665,385.00  665,385.00
# mean        2,021.27                7.12         7.71       53.17    5,350.46
# std             1.06                7.82     1,254.76       21.20    2,115.71
# min         2,019.00                0.00         0.00        1.00      111.00
# 25%         2,021.00                2.00         0.00       46.00    4,620.00
# 50%         2,022.00                4.00         0.00       47.00    4,773.00
# 75%         2,022.00               10.00         1.00       69.00    6,910.00
# max         2,022.00               50.00   800,000.00       99.00    9,900.00
#
#       ESTADO_RENOVACION TIPO_CATEGORIA ORG_JURIDICA  Sector_CCB      tamano  \
# count        665,378.00     665,385.00   665,385.00  665,385.00  665,385.00
# mean               2.94           1.42         4.45       26.43        1.07
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('C:/Users/1032452285/Downloads/base_entrenamiento_2021_22.csv')

print(df.head())
print(df.shape)
print(df.columns)
#df = df.drop('Unnamed: 0', axis=1)
df= df.drop (['NOMBRE','iddx','Usuario','DocumentoUsuario','DocumentoEmpresa','NUM_ID','NUM_MATRICULA','NOMBRE'], axis=1)
print(df.head())
print(df.shape)
# Out:
#                               NOMBRE  NUM_MATRICULA  NUM_ID    iddx  \
# 0           HORACIO  RODRIGUEZ LOPEZ        1232815  226391  259209
# 1  MAURICIO SEBASTIAN CORONEL CHANGO        3268235  315000  256521
# 2                JUDITH TELLO ACOSTA        2630809  351094  254835
# 3            VICTOR MANUEL NIÑO RUIZ        2738322  413177  260524
# 4    VERONICA MARGARITA MOREIRA POZO        2712685  418141  255113
#
#                              Usuario  DocumentoUsuario  DocumentoEmpresa  \
# 0            HORACIO RODRIGUEZ LOPEZ         2263916.0            226391
# 1  MAURICIO SEBASTIAN CORONEL CHANGO          315000.0            315000
# 2                JUDITH TELLO ACOSTA          351094.0            351094
# 3            VICTOR MANUEL NIÑO RUIZ          413177.0            413177
# 4    VERONICA MARGARITA MOREIRA POZO          418141.0            418141
#
#    ULT_ANO_RENOVA  AÑOS_FUNCIONAMIENTO  PERSONAL2022  ...  \
# ...

# %%
h = .02  # step size in the mesh

names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %%
X = df.drop(['programa'], axis=1).values
pca = PCA(n_components=2,svd_solver='full')
X = pca.fit_transform(X)
y = df['programa']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X = df.drop(['programa'], axis=1).values
Y = df['programa']
X = StandardScaler().fit_transform(X)

X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size = 0.3, random_state = 101)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
import matplotlib.pyplot as plt
# Preprocessing :
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report,confusion_matrix
from itertools import product

# Classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
import matplotlib.pyplot as plt
cv = CountVectorizer()
cv.fit(df)
print (len(cv.vocabulary_))
print (cv.get_feature_names())

X_train = cv.transform(df.drop(['programa'], axis=1))
svm = LinearSVC()
svm.fit(X, Y)
# Out:
# 27
# ['años_funcionamiento', 'ciiufinal', 'ciudad', 'estado_renovacion', 'lnactivo2022', 'lning_act_ord2022', 'lnliquidez', 'lnpatrimonio2022', 'lnproductividad', 'lnutil_opera2022', 'org_juridica', 'personal2022', 'programa', 'sector_ccb', 'subseccion', 'tamano', 'tasa_activo2020', 'tasa_activo2021', 'tasa_activo2022', 'tasa_ing_act_ord2020', 'tasa_ing_act_ord2021', 'tasa_ing_act_ord2022', 'tasa_patrimonio2020', 'tasa_patrimonio2021', 'tasa_patrimonio2022', 'tipo_categoria', 'ult_ano_renova']
# LinearSVC()

# %%
trainedsvm = svm.fit(X_Train, Y_Train)
predictionsvm = trainedsvm.predict(X_Test)
print(confusion_matrix(Y_Test,predictionsvm))
print(classification_report(Y_Test,predictionsvm))
# Out:
# [[761 109   1]
#  [153 306   0]
#  [ 37  14   1]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.84       871
#            1       0.71      0.67      0.69       459
#            2       0.50      0.02      0.04        52
#
#     accuracy                           0.77      1382
#    macro avg       0.67      0.52      0.52      1382
# weighted avg       0.76      0.77      0.76      1382

# %%
dfc = pd.read_csv('C:/Users/1032452285/Downloads/base_entrenamiento_2021_22_completa.csv')

# %%
#df = df.drop('Unnamed: 0', axis=1)
dfc= dfc.drop (['NOMBRE','iddx','Usuario','DocumentoUsuario','DocumentoEmpresa','NUM_ID','NUM_MATRICULA','programa'], axis=1)

# %%
dfc.describe().applymap('{:,.2f}'.format)
# Out:
#       ULT_ANO_RENOVA AÑOS_FUNCIONAMIENTO PERSONAL2022  subseccion   CIIUFINAL  \
# count     665,385.00          665,385.00   665,385.00  665,385.00  665,385.00
# mean        2,021.27                7.12         7.71       53.17    5,350.46
# std             1.06                7.82     1,254.76       21.20    2,115.71
# min         2,019.00                0.00         0.00        1.00      111.00
# 25%         2,021.00                2.00         0.00       46.00    4,620.00
# 50%         2,022.00                4.00         0.00       47.00    4,773.00
# 75%         2,022.00               10.00         1.00       69.00    6,910.00
# max         2,022.00               50.00   800,000.00       99.00    9,900.00
#
#       ESTADO_RENOVACION TIPO_CATEGORIA ORG_JURIDICA  Sector_CCB      tamano  \
# count        665,378.00     665,385.00   665,385.00  665,385.00  665,385.00
# mean               2.94           1.42         4.45       26.43        1.07
# ...

# %%
dfc['ULT_ANO_RENOVA'].value_counts()
# Out:
# 2022    406393
# 2021    114366
# 2019     80261
# 2020     64365
# Name: ULT_ANO_RENOVA, dtype: int64

# %%
dfc=dfc.dropna()
dfc.describe().applymap('{:,.2f}'.format)
# Out:
#       ULT_ANO_RENOVA AÑOS_FUNCIONAMIENTO PERSONAL2022  subseccion   CIIUFINAL  \
# count     665,378.00          665,378.00   665,378.00  665,378.00  665,378.00
# mean        2,021.27                7.12         7.71       53.17    5,350.45
# std             1.06                7.82     1,254.76       21.20    2,115.72
# min         2,019.00                0.00         0.00        1.00      111.00
# 25%         2,021.00                2.00         0.00       46.00    4,620.00
# 50%         2,022.00                4.00         0.00       47.00    4,773.00
# 75%         2,022.00               10.00         1.00       69.00    6,910.00
# max         2,022.00               50.00   800,000.00       99.00    9,900.00
#
#       ESTADO_RENOVACION TIPO_CATEGORIA ORG_JURIDICA  Sector_CCB      tamano  \
# count        665,378.00     665,378.00   665,378.00  665,378.00  665,378.00
# mean               2.94           1.42         4.45       26.43        1.07
# ...

# %%
predictiondfc=trainedsvm.predict(dfc)

# %%
pred_svm=pd.DataFrame(predictiondfc,columns=['programa_svm'])

# %%
DFC=pd.merge(dfc, pred_svm, left_index=True, right_index=True)

# %%
DFC['programa_svm'].value_counts()
# Out:
# 1    665286
# 2        68
# 0        17
# Name: programa_svm, dtype: int64
